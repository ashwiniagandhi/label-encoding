# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
iris=pd.read_csv('C:\\Users\\SAGAR\\Documents\\ashwini\\pandas\\ChanDarren_RaiTaran_Lab2a.csv')
iris
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
print(iris.shape)
# Out:
# (891, 12)

# %%
print(iris.groupby('Sex').size())
# Out:
# Sex
# female    314
# male      577
# dtype: int64

# %%
sns.set_style("darkgrid")  
sns.FacetGrid(iris, hue="Sex", size=3).map(plt.scatter, "sibsp", "cabin").add_legend()  
plt.title('pune city')  
plt.xlabel('X-Label')  
plt.ylabel('Y-Label')  
plt.show()
# Out:
# C:\Program Files\anaconda2\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-532f586cac40> in <module>
#       1 sns.set_style("darkgrid")
# ----> 2 sns.FacetGrid(iris, hue="Sex", size=3).map(plt.scatter, "sibsp", "cabin").add_legend()
#       3 plt.title('pune city')
#       4 plt.xlabel('X-Label')
#       5 plt.ylabel('Y-Label')
#
# C:\Program Files\anaconda2\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     742
#     743             # Get the actual data we are going to plot with
# --> 744             plot_data = data_ijk[list(args)]
#     745             if self._dropna:
#     746                 plot_data = plot_data.dropna()
#
# ...
